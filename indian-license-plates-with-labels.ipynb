# %%
import numpy as np
import pandas as pd
import os
for dirname,_,filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname,filename))
import cv2
import matplotlib.pyplot as plt
# !pip install pytesseract 
import pytesseract
from PIL import Image
# Out:
# /kaggle/input/indian-license-plates-with-labels/labels/License (1632).txt
# /kaggle/input/indian-license-plates-with-labels/labels/License (1521).txt
# /kaggle/input/indian-license-plates-with-labels/labels/License (1802).txt
# /kaggle/input/indian-license-plates-with-labels/labels/License (826).txt
# /kaggle/input/indian-license-plates-with-labels/labels/License (1432).txt
# /kaggle/input/indian-license-plates-with-labels/labels/License (297).txt
# /kaggle/input/indian-license-plates-with-labels/labels/License (26).txt
# /kaggle/input/indian-license-plates-with-labels/labels/License (834).txt
# /kaggle/input/indian-license-plates-with-labels/labels/License (808).txt
# /kaggle/input/indian-license-plates-with-labels/labels/License (68).txt
# /kaggle/input/indian-license-plates-with-labels/labels/License (436).txt
# /kaggle/input/indian-license-plates-with-labels/labels/License (56).txt
# /kaggle/input/indian-license-plates-with-labels/labels/License (546).txt
# ...

# %%
# !chmod+r/kaggle/input/indian-license-plates-with-labels

paths=[]
for dirnames,_,filenames in os.walk('/kaggle/input/indian-license-plates-with-labels/images'):
    for filname in filenames:
        paths+=[(os.path.join(dirname,filname))]
# Out:
# /bin/bash: line 1: chmod+r/kaggle/input/indian-license-plates-with-labels: No such file or directory

# %%
for i in[0,1,2,5,16,21,30,36,38,45,49,52,57,62]:
    path=paths[i]
    img=cv2.imread(path)
    print(i)
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.show()
    text=pytesseract.image_to_string(img)
    print(text)
# Out:
# 0
# “MH 14000707;
#
# 1
# MH.01.AX.7656
#
# 2
# IMH'02 BY S140H
#
# 5
# MH 44 DN 8522
#
# 16
# ‘TN-06-F-1742.
#
# 21
# MH.02.B1.4626 |
#
# 30
# “WB 06 9998:
#
# 36
# /MH.12,ET.6622_
#
# 38
# WB 02Y 7511)
#
# 45
# TNOZAQ8660
#
# 49
# ~~ Ad-0651 ©
#
# 52
# ASS
#
# 57
# \ntrae 2618 |
#
# 62
